# %%
a=10
b=20.5
print(a+b)
# Out:
# 30.5

# %%
a=10
b="ten"
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 a=10
#       2 b="ten"
# ----> 3 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#both must be in string type
fname="Kavya"
sname="Reddy"
print(fname+sname)
# Out:
# KavyaReddy

# %%
a=10
b=20
print(a*b)
# Out:
# 200

# %%
#now it performs repetition
a=10
b="20"
print(a*b)
# Out:
# 20202020202020202020

# %%
a="ten"
b="two"
print(a*b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 a="ten"
#       2 b="two"
# ----> 3 print(a*b)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
a=20
b="Kavya"
print(a*b)
# Out:
# KavyaKavyaKavyaKavyaKavyaKavyaKavyaKavyaKavyaKavyaKavyaKavyaKavyaKavyaKavyaKavyaKavyaKavyaKavyaKavya

# %%
a=2
b=5
a+b
