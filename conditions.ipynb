# %%
sal=int(input("enter salary:"))
if sal>30000:
    print("eligible for EMI")
else:
    print("not eligible for EMI")
# Out:
# enter salary: 40000
# eligible for EMI

# %%
num=int(input("Enter number:"))
if num>=100 and num<=999:
    print("given number is a 3 digit number")
else:
    print("given number is not a 3 digit number")
# Out:
# Enter number: 29
# given number is not a 3 digit number
